# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly
from numpy.fft import fft, fftfreq, ifft, rfft

df = pd.read_csv('./data/train/Stopper/100cm_AS_00003.csv', header=None)
# fft = np.fft.fft(data,n=data.size)/data.size
# print(fft)
fs= 1e6
for index, row in df.iterrows():
    fft_data = fft(row, n=row.size)/row.size
    freq = fftfreq(row.size, d=1/fs)
    fig, ax = plt.subplots(1, 1)
    plt.plot(freq, np.abs(fft_data))
# Out:
# /Users/anujjoshi/miniconda3/envs/uni_project/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
cut_f_signal[(freq<30000)] = 0
signal = ifft(cut_f_signal)

cut_high_signal = signal.copy()
cut_high_signal[(freq>50000)] = 0
signal = ifft(cut_high_signal)

for n in signal:
    a = a+1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d1a7561a556f> in <module>
#       1
#       2
# ----> 3 cut_f_signal[(freq<30000)] = 0
#       4 signal = ifft(cut_f_signal)
#       5
#
# NameError: name 'cut_f_signal' is not defined

# %%
abs_signal = []
for index, n in enumerate(np.abs(cut_high_signal)):
    if n != 0:
        abs_signal.append(n)
# freq = fftfreq(len(abs_signal), d=1/fs)
# for n in freq:
#     print(n)
# freq = fftfreq(len(signal), d=1/fs)

# %%
df_wall = pd.read_csv('./data/train/Wall_Collection/100cm_AS_00005.csv', header=None)
# fft = np.fft.fft(data,n=data.size)/data.size
# print(fft)
fs= 1e6
for index, row in df.iterrows():
    fft_datadf_wall = fft(row, n=row.size)/row.size
    freqdf_wall = fftfreq(row.size, d=1/fs)
    fig, ax = plt.subplots(1, 1)
    plt.plot(freqdf_wall, np.abs(fft_datadf_wall))

# %%
y = ['Stopper']*71 + ['Wall']*40

# %%
X = result+ result
# Out:
# ['Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Stopper', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 'Wall', 
# ...
